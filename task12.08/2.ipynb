# %%
directions = ["Схід", "Південь", "Північ"]
losses_per_day = [30, 45, 25, 60]

# %%
defirections = ["Схід", "Південь", "Північ"]
directions.append("захід")
print(directions)
# Out:
# ['Схід', 'Південь', 'Північ', 'захід', 'захід', 'захід', 'захід', 'захід']

# %%
losses_per_day = [30,45,25,60]
losses_per_day.sort(reverse=True)
print(losses_per_day)
# Out:
# [60, 45, 30, 25]

# %%
losses_per_day[2] = 50
losses_per_day
# Out:
# [60, 45, 50, 25]

# %%
losses_per_day.clear()

# %%
coordinates = (23.45,54.32)
print(coordinates)
# Out:
# (23.45, 54.32)

# %%
coordinates.index(54.32)
# Out:
# 1

# %%
MyTuple = (1, 2, 2, 4, 2)
MyTuple.count(3)
# Out:
# 0

# %%
MyTuple = (1, 2, 2, 4, 2)
MyTuple.count(2)
# Out:
# 3

# %%
x=3
if MyTuple.count(x) >0
    print(MyTuple)
else:
    print(f"Element {x}")
# Out:
#   Cell In[18], line 2
#     if MyTuple.count(x) >0
#                           ^
# SyntaxError: expected ':'

# %%
unit_losses = {
    "1-а мехбр": 120,
    "2-а танкбр": 80,
    "3-я артбатр": 45
}

# %%
for data in MyTuple:
    print(data)
# Out:
# 1
# 2
# 2
# 4
# 2
