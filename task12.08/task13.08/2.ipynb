# %% [markdown]
# 📝 Практичні завдання:
# 1. Створити список напрямків, по яких ведеться аналіз.
# 2. Створити словник із втратами підрозділів та порахувати сумарні втрати.
# 3. Побудувати множину типів виявленої техніки на основі списку спостережень.
# 4. Вивести підрозділи, втрати яких перевищують 50 осіб.

# %%
# 1. Створити список напрямків, по яких ведеться аналіз.
defirections = ["виявлення", "оцінка"]
print(defirections)
# Out:
# ['виявлення', 'оцінка']

# %%
# 2. Створити словник із втратами підрозділів та порахувати сумарні втрати.
losses = {
    "1бр - ": 10,
    "2обр - " : 5,
    "3омбр - ": 0
}
print(losses)
total = sum(losses.values())
print(total)
# Out:
# {'1бр - ': 10, '2обр - ': 5, '3омбр - ': 0}
# 15

# %%
#3. Побудувати множину типів виявленої техніки на основі списку спостережень.

OVT = ["танк", "танк", "БМП", "вантажівка"]

print(OVT)
OVT_types = set(OVT)
print(OVT_types)
# Out:
# ['танк', 'танк', 'БМП', 'вантажівка']
# {'БМП', 'танк', 'вантажівка'}

# %%
# 4. Вивести підрозділи, втрати яких перевищують 50 осіб.
