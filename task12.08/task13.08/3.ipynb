# %%
# 1. Оголошення функцій
# ✅ Синтаксис:
def function_name(parameters):
    # тіло функції
    return result #вихід з функції

# %%
# функція зі списку оберає середне

def avareg_of_list(my_list):
    if len(my_list) ==0:
        retern 0
    else:
        retrn sum(my_list)/len(my_list)
