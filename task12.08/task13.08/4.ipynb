# %%
def avareg_of_list(my_list):
    if len(my_list) ==0:
        return 0
    else:
        return sum(my_list) / len(my_list)

# %%
list1 = [10, 20, 30, 47, 50]
avareg_of_list(list1)
# Out:
# 31.4

# %%
# Практичні завдання:
# Створіть функцію, яка на основі втрат і чисельності ворога оцінює результативність дій.
# Напишіть функцію для обрахунку середніх втрат за кілька днів.
# Імпортуйте модуль random і змоделюйте напрямок наступу.
#Створіть власний модуль із функціями для оцінки логістичної готовності.

# %%
# 1. Створіть функцію, яка на основі втрат і чисельності ворога оцінює результативність дій.
def vtr(a):
    # a=int(input("Введіть відсоток втрат: "))
    if a >= 0 and a <= 20:
        return("Мінімальні втрати")
    elif a >= 21 and a <= 40:
        return("Невеликі втрати")
    elif a >= 41 and a <= 60:
        return("Середні втрати") 
    elif a >= 61 and a <= 80:
        return("Великі втрати")
    elif a >= 81 and a <= 100:
        return("Катастрофічні втрати")
        
print (vtr(30))
# Out:
# Невеликі втрати

# %%
print(vtr(x))x = int(input("Введіть відсоток втрат: "))
# Out:
# Середні втрати

# %%
# 2. Напишіть функцію для обрахунку середніх втрат за кілька днів.
def my_median(x,y,z ):
    return (x+y+z)/3

# %%
print(my_median(15, 100, 77))
# Out:
# 64.0

# %%
# Імпортуйте модуль random і змоделюйте напрямок наступу.
import math
import random

# %%
random.choice()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 random.choice()
#
# TypeError: Random.choice() missing 1 required positional argument: 'seq'
